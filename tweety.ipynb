# %%
# !pip install tweepy

# %%
import tweepy

# Twitter API credentials
API_KEY = "LaYsrUm0QKsijkTjGHRrc1jQ3"
API_KEY_SECRET = "1UFODjQlJHMupgZU9xOuZ7ZfDP7ZAoZ2VQNBR3umYewhULVtyU"
ACCESS_TOKEN = "3160182558-qrNWFkYy5w6w5h44knigJXU4QmORnMluynWXnGr"
ACCESS_TOKEN_SECRET = "LGOcl1Hbz4WfD6tBVR91MkNPXxcI0aadTfD7XfXeAeGzI"

# Authenticate to Twitter
auth = tweepy.OAuth1UserHandler(API_KEY, API_KEY_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# Post a tweet
try:
    api.update_status("Hello, world! This is my first tweet using Tweepy!")
    print("Tweet posted successfully!")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: 403 Forbidden
# 453 - You currently have access to a subset of X API V2 endpoints and limited v1.1 endpoints (e.g. media post, oauth) only. If you need access to this endpoint, you may need a different access level. You can learn more here: https://developer.x.com/en/portal/product

# %%
import tweepy
import os

# Get your Twitter API credentials. You can get these by
# creating a Twitter developer account and creating an app.
# You can also use environment variables as shown below.

consumer_key = "LaYsrUm0QKsijkTjGHRrc1jQ3"
consumer_secret = "1UFODjQlJHMupgZU9xOuZ7ZfDP7ZAoZ2VQNBR3umYewhULVtyU"
access_token = "3160182558-qrNWFkYy5w6w5h44knigJXU4QmORnMluynWXnGr"
access_token_secret = "LGOcl1Hbz4WfD6tBVR91MkNPXxcI0aadTfD7XfXeAeGzI"


# Authenticate to Twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# Create API object
api = tweepy.API(auth)

# Create a tweet
try:
    api.update_status("Hello Tweepy! This is my first tweet using Python.")
    print("Tweet posted successfully!")
except tweepy.TweepyException as e:
    print(f"Error posting tweet: {e}")
# Out:
# Error posting tweet: 403 Forbidden
# 453 - You currently have access to a subset of X API V2 endpoints and limited v1.1 endpoints (e.g. media post, oauth) only. If you need access to this endpoint, you may need a different access level. You can learn more here: https://developer.x.com/en/portal/product
